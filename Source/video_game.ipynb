# %%
import numpy as np          #the dataset contains some numerical category so i used numpy
import pandas as pd         #for read, clean, analyze and group the data i used pandas
import matplotlib.pyplot as plt   #for creating and identifying different types of charts, trends and patterns i used matplotlib

# %% [markdown]
# 1.LOAD DATASET

# %% [markdown]
# After Importing the modules We have to read the file

# %%
games = pd.read_csv(r"C:\Users\Jenifer\OneDrive\Desktop\vid game\Datasets\vgsales.csv")

# %% [markdown]
# 2.EXPLORE THE DATASET

# %% [markdown]
# To view the dataset we have to use the function(head()) it shows the preview of the dataset

# %%
games.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %% [markdown]
# To identify the type of the dataset we use type() function

# %%
type(games)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Here, we have to calculate 'How many elements are in the dataset' for that we use shape(method)

# %%
games.shape
# Out:
# (16598, 11)

# %% [markdown]
# To get the information of the dataset, the info() function is used

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
games.tail()
# Out:
#         Rank                                              Name Platform  \
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year     Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 16593  2002.0  Platform       Kemco      0.01      0.00       0.0
# 16594  2003.0   Shooter  Infogrames      0.01      0.00       0.0
# 16595  2008.0    Racing  Activision      0.00      0.00       0.0
# 16596  2010.0    Puzzle    7G//AMES      0.00      0.01       0.0
# 16597  2003.0  Platform     Wanadoo      0.01      0.00       0.0
#
#        Other_Sales  Global_Sales
# 16593          0.0          0.01
# 16594          0.0          0.01
# ...

# %%
games.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
games.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %% [markdown]
# 3.DATA CLEANING

# %% [markdown]
# To check missing values

# %%
games.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
games[games.isnull().any(axis=1)]
# Out:
#         Rank                             Name Platform    Year         Genre  \
# 179      180                  Madden NFL 2004      PS2     NaN        Sports
# 377      378                 FIFA Soccer 2004      PS2     NaN        Sports
# 431      432       LEGO Batman: The Videogame      Wii     NaN        Action
# 470      471       wwe Smackdown vs. Raw 2006      PS2     NaN      Fighting
# 607      608                   Space Invaders     2600     NaN       Shooter
# ...      ...                              ...      ...     ...           ...
# 16427  16430                     Virtua Quest       GC     NaN  Role-Playing
# 16493  16496                       The Smurfs      3DS     NaN        Action
# 16494  16497  Legends of Oz: Dorothy's Return      3DS  2014.0        Puzzle
# 16543  16546           Driving Simulator 2011       PC  2011.0        Racing
# 16553  16556                   Bound By Flame     X360  2014.0  Role-Playing
#
# ...

# %% [markdown]
# If it is True then, there are some null values found

# %%
games.isnull().any()
# Out:
# Rank            False
# Name            False
# Platform        False
# Year             True
# Genre           False
# Publisher        True
# NA_Sales        False
# EU_Sales        False
# JP_Sales        False
# Other_Sales     False
# Global_Sales    False
# dtype: bool

# %% [markdown]
# To remove dupicates

# %%
games.drop_duplicates(inplace=True)

# %% [markdown]
# TO FILL THE MISSING VALUES I USED FILLNA()

# %%
games["Publisher"] = games["Publisher"].fillna("Unknown")

# %%
games["Year"]=pd.to_numeric(games["Year"],errors="coerce") #It converts the 'year' column into numeric data type and the parameter tells "if a value can't converted to a number replace it with NaN"
games = games.dropna(subset=["Year"])
games["Year"]=games["Year"].astype(int)
# Out:
# C:\Users\Jenifer\AppData\Local\Temp\ipykernel_7484\2287415017.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   games["Year"]=games["Year"].astype(int)

# %% [markdown]
# 5.FEATURE ENGINEERING - creating new columns from the existing data to make analysis more easier

# %%
#Instead of analysing every single year,its more useful to analyze decades
#BY this we can answer for which decade sold the most games?
#and which decade released the most game
games["Decade"]=(games["Year"]//10)*10

# %% [markdown]
# To create Sales Category

# %%
#Looking at exact sales values for thousands of games can be difficult. 
#Instead of that classified into categories
#pd.cut() to divide continuous num data into categories
#bins - The range(intervals) for each category
games["Sales_Category"] = pd.cut(
    games["Global_Sales"],
    bins=[0,1,5,10,60],
    labels=["Low","Medium","High","Blockbuster"]
)

# %% [markdown]
# Publisher game count - A publisher release many games but not all of them become successful

# %%
publisher_games = games.groupby("Publisher")["Name"].count()
print(publisher_games)
# Out:
# Publisher
# 10TACLE Studios                  3
# 1C Company                       3
# 20th Century Fox Video Games     5
# 2D Boy                           1
# 3DO                             36
#                                 ..
# id Software                      1
# imageepoch Inc.                  2
# inXile Entertainment             1
# mixi, Inc                        1
# responDESIGN                     2
# Name: Name, Length: 576, dtype: int64

# %% [markdown]
# 6.EXPLORATORY DATA ANALYSIS(EDA)

# %% [markdown]
# 1.TOTAL GLOBAL SALES - KPI

# %%
games["Global_Sales"].sum()
# Out:
# np.float64(8820.36)

# %% [markdown]
# TOTAL GAMES - KPI

# %%
games["Name"].nunique()
# Out:
# 11360

# %% [markdown]
# TOTAL PUBLISHERS - KPI

# %%
games["Publisher"].nunique()
# Out:
# 576

# %% [markdown]
# TOTAL PLATFORMS - KPI

# %%
games["Platform"].nunique()
# Out:
# 31

# %% [markdown]
# TOTAL GENRE - KPI

# %%
games["Genre"].nunique()
# Out:
# 12

# %% [markdown]
# AVERAGE GLOBAL SALES - KPI

# %%
games["Global_Sales"].mean()
# Out:
# np.float64(0.5402315183438476)

# %% [markdown]
# HIGHEST SELLING GAME

# %%
#.loc - accesses data using row label(index) and column name
#Syntax (df.loc[row,column])
games.loc[games["Global_Sales"].idxmax(),"Name"]
# Out:
# 'Wii Sports'

# %% [markdown]
# HIGHEST GLOBAL SALES

# %%
games["Global_Sales"].max()
# Out:
# 82.74

# %% [markdown]
# 2.TOP 10 BEST-SELLING GAMES - Identifies successfull products

# %%
games.nlargest(10, "Global_Sales")[["Name", "Platform", "Global_Sales"]]
# Out:
#                         Name Platform  Global_Sales
# 0                 Wii Sports      Wii         82.74
# 1          Super Mario Bros.      NES         40.24
# 2             Mario Kart Wii      Wii         35.82
# 3          Wii Sports Resort      Wii         33.00
# 4   Pokemon Red/Pokemon Blue       GB         31.37
# 5                     Tetris       GB         30.26
# 6      New Super Mario Bros.       DS         30.01
# 7                   Wii Play      Wii         29.02
# 8  New Super Mario Bros. Wii      Wii         28.62
# 9                  Duck Hunt      NES         28.31

# %% [markdown]
# 3.TOP 10 PUBLISHERS - Finds market leaders

# %%
games.groupby("Publisher")["Global_Sales"].sum().sort_values(ascending=False).head(10)
# Out:
# Publisher
# Nintendo                        1784.43
# Electronic Arts                 1093.39
# Activision                       721.41
# Sony Computer Entertainment      607.28
# Ubisoft                          473.54
# Take-Two Interactive             399.30
# THQ                              340.44
# Konami Digital Entertainment     278.56
# Sega                             270.70
# Namco Bandai Games               253.65
# Name: Global_Sales, dtype: float64

# %% [markdown]
# 4.BEST PLATFORMS - Guides platforms investment decisions

# %%
games.groupby("Platform")["Global_Sales"].sum().sort_values(ascending=False)
# Out:
# Platform
# PS2     1233.46
# X360     969.61
# PS3      949.35
# Wii      909.81
# DS       818.96
# PS       727.39
# GBA      313.56
# PSP      291.71
# PS4      278.10
# PC       255.05
# GB       254.42
# XB       252.09
# NES      251.07
# 3DS      246.28
# N64      218.21
# SNES     200.05
# GC       197.14
# XOne     141.06
# 2600      86.57
# WiiU      81.86
# PSV       61.63
# SAT       33.59
# GEN       28.36
# DC        15.97
# SCD        1.87
# NG         1.44
# WS         1.42
# TG16       0.16
# 3DO        0.10
# GG         0.04
# PCFX       0.03
# Name: Global_Sales, dtype: float64

# %% [markdown]
# 5.MOST POPULAR GENRE - Helps prioritize game development

# %%
games.groupby("Genre")["Global_Sales"].sum().sort_values(ascending=False)
# Out:
# Genre
# Action          1722.88
# Sports          1309.24
# Shooter         1026.20
# Role-Playing     923.84
# Platform         829.15
# Misc             797.62
# Racing           726.77
# Fighting         444.05
# Simulation       390.16
# Puzzle           242.22
# Adventure        234.80
# Strategy         173.43
# Name: Global_Sales, dtype: float64

# %% [markdown]
# 6.REGIONAL SALES - Supports region-specific marketing

# %%
games[["NA_Sales","EU_Sales","JP_Sales","Other_Sales"]].sum()
# Out:
# NA_Sales       4333.43
# EU_Sales       2409.12
# JP_Sales       1284.30
# Other_Sales     789.01
# dtype: float64

# %% [markdown]
# 7.SALES BY YEAR - Reveals long term market trends

# %%
games.groupby("Year")["Global_Sales"].sum()
# Out:
# Year
# 1980     11.38
# 1981     35.77
# 1982     28.86
# 1983     16.79
# 1984     50.36
# 1985     53.94
# 1986     37.07
# 1987     21.74
# 1988     47.22
# 1989     73.45
# 1990     49.39
# 1991     32.23
# 1992     76.16
# 1993     45.98
# 1994     79.17
# 1995     88.11
# 1996    199.15
# 1997    200.98
# 1998    256.47
# 1999    251.27
# 2000    201.56
# 2001    331.47
# 2002    395.52
# 2003    357.85
# 2004    419.31
# 2005    459.94
# 2006    521.04
# 2007    611.13
# 2008    678.90
# 2009    667.30
# 2010    600.45
# 2011    515.99
# 2012    363.54
# 2013    368.11
# 2014    337.05
# 2015    264.44
# 2016     70.93
# 2017      0.05
# 2020      0.29
# Name: Global_Sales, dtype: float64

# %% [markdown]
# 8.NUMBER OF GAMES RELEASED EACH YEAR - Shows industry growth anad competition

# %%
games.groupby("Year")["Name"].count()
# Out:
# Year
# 1980       9
# 1981      46
# 1982      36
# 1983      17
# 1984      14
# 1985      14
# 1986      21
# 1987      16
# 1988      15
# 1989      17
# 1990      16
# 1991      41
# 1992      43
# 1993      60
# 1994     121
# 1995     219
# 1996     263
# 1997     289
# 1998     379
# 1999     338
# 2000     349
# 2001     482
# 2002     829
# 2003     775
# 2004     763
# 2005     941
# 2006    1008
# 2007    1202
# 2008    1428
# 2009    1431
# 2010    1259
# 2011    1139
# 2012     657
# 2013     546
# 2014     582
# 2015     614
# 2016     344
# 2017       3
# 2020       1
# Name: Name, dtype: int64

# %% [markdown]
# 9.BEST PUBLISHER IN EACH GENRE - Highlights publishers strength

# %%
games.groupby(["Genre","Publisher"])["Global_Sales"].sum()
# Out:
# Genre     Publisher
# Action    20th Century Fox Video Games              1.72
#           3DO                                       6.28
#           505 Games                                 3.22
#           5pb                                       0.13
#           989 Studios                               2.63
#                                                     ...
# Strategy  Vivendi Games                             0.62
#           Warner Bros. Interactive Entertainment    2.86
#           Westwood Studios                          1.55
#           Zoo Digital Publishing                    0.09
#           Zushi Games                               0.07
# Name: Global_Sales, Length: 1823, dtype: float64

# %% [markdown]
# 10.BEST PLATFORM IN EACH REGION - Supports regional launch strategies

# %%
games.groupby("Platform")[["NA_Sales", "EU_Sales", "JP_Sales"]].sum()
# Out:
#           NA_Sales  EU_Sales  JP_Sales
# Platform
# 2600         80.78      4.86      0.00
# 3DO           0.00      0.00      0.10
# 3DS          78.03     58.30     97.30
# DC            5.43      1.69      8.56
# DS          388.56    194.07    175.02
# GB          113.64     47.51     85.12
# GBA         184.12     74.59     46.56
# GC          131.94     38.32     21.34
# GEN          19.27      5.52      2.67
# GG            0.00      0.00      0.04
# N64         138.91     41.03     33.76
# NES         125.94     21.15     98.65
# NG            0.00      0.00      1.44
# PC           92.10    137.64      0.17
# PCFX          0.00      0.00      0.03
# PS          334.71    212.38    139.78
# PS2         572.92    332.63    137.54
# PS3         388.90    340.47     79.21
# PS4          96.80    123.70     14.30
# PSP         107.09     67.16     75.89
# PSV          16.07     16.27     20.89
# SAT           0.72      0.54     32.26
# SCD           1.00      0.36      0.45
# ...

# %% [markdown]
# 7.VISUALIZATION

# %% [markdown]
# 1.TOP PLATFORMS - Which gaming platforms generated the highest sales?

# %%
platform_sales = games.groupby("Platform")["Global_Sales"].sum().sort_values()
platform_sales.plot(kind="barh", figsize=(10,6))
plt.title("Top Platforms by Global sales")
plt.xlabel("Global Sales")
plt.ylabel("Platforms")
plt.show()

# %% [markdown]
# 2.TOP GENRES - Which genres are most popular?

# %%
genre_sales=games.groupby("Genre")["Global_Sales"].sum()
genre_sales.plot(kind="bar")
plt.title("Genre Sales")
plt.show()

# %% [markdown]
# 3.SALES TREND - How have video games sales changed over time?

# %%
year_sales=games.groupby("Year")["Global_Sales"].sum()
year_sales.plot(kind="line", marker="o")
plt.title("Global Sales Trend")
plt.show()

# %% [markdown]
# 4.REGIONAL SALES - Which region contributes the most sales?

# %%
region_sales=games[['NA_Sales','EU_Sales', 'JP_Sales', 'Other_Sales']].sum()
region_sales.plot(kind="pie", autopct="%1.1f%%")
plt.title("Regional Sales Distribution")
plt.ylabel("")
plt.show()

# %% [markdown]
# 5.TOP PUBLISHERS - Which publishers dominate the market?

# %%
publisher_sales=games.groupby("Publisher")["Global_Sales"].sum().sort_values(ascending=False).head(10)
publisher_sales.plot(kind="bar")
plt.title("Top Publishers")
plt.show()

# %% [markdown]
# 6.TOP 10 BEST-SELLING GAMES - Easy to compare long game names

# %%
top_games = games.nlargest(10, "Global_Sales")
plt.figure(figsize=(10,6))
plt.barh(top_games["Name"], top_games["Global_Sales"])
plt.title("Top 10 Best-Selling Video Games")
plt.xlabel("Global Sales (Millions)")
plt.ylabel("Game Name")
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# 7.GAMES RELEASED BY YEAR - Show release trends

# %%
games_per_year = games.groupby("Year")["Name"].count()
plt.figure(figsize=(12,6))
plt.plot(games_per_year.index,
         games_per_year.values)
plt.title("Games Released Each Year")
plt.xlabel("Year")
plt.ylabel("Number of Games")
plt.grid(True)
plt.show()

# %% [markdown]
# 8.SALES BY DECADE - Compare decades

# %%
decade_sales = games.groupby("Decade")["Global_Sales"].sum()
plt.figure(figsize=(8,5))
decade_sales.plot(kind="bar")
plt.title("Global Sales by Decade")
plt.xlabel("Decade")
plt.ylabel("Global Sales (Millions)")
plt.show()

# %% [markdown]
# 9.PLATFORM PERFORMANCE BY REGION - Compare multiple regions across platforms

# %%
platform_region = games.groupby("Platform")[["NA_Sales","EU_Sales","JP_Sales"]].sum()
platform_region.plot(kind="bar",figsize=(12,6))
plt.title("Platform Performance by Region")
plt.xlabel("Platform")
plt.ylabel("Sales (Millions)")
plt.show()

# %% [markdown]
# 10.SALES CATEGORY DISTRIBUTION - Show distribution across categories

# %%
sales_category = games["Sales_Category"].value_counts()
plt.figure(figsize=(7,5))
sales_category.plot(kind="bar")
plt.title("Sales Category Distribution")
plt.xlabel("Sales Category")
plt.ylabel("Number of Games")
plt.show()
